# %% [markdown]
# # Trabalho IA2
# Devo apostar no time X (Arsenal por enquanto)
# Considerando as variáveis:
#
# 1. Jogo em casa
# 2. qualidade dos jogadores do time X
# 3. Qualidade dos jogadores do adversário
# 4. Odds da vitoria/empate/derrota
# 5. Algum outro atributo do time
#
# Considerando as decisões:
#
# 1. Apostar na vitória
# 2. Apostar no empate
# 3. Apostar na derrota

# %%
# Importar as libs necesárias
import numpy as np 
import pandas as pd 
import sqlite3
import matplotlib.pyplot as plt

# %%
# Conexão com a DB
database = sqlite3.connect('database.sqlite')
# Dados da tabela
tables = pd.read_sql("""SELECT *
                        FROM sqlite_master
                        WHERE type='table';""", database)
                        

# Importar dados do Arsenal
matches = pd.read_sql_query("SELECT * FROM 'Match' where season = \"2015/2016\" AND (home_team_api_id == 9825 OR away_team_api_id == 9825)", database)
# Filtrar informacoes
new_matches = matches[['id', 'season', 'match_api_id','home_team_api_id','home_team_goal','away_team_goal','home_player_1','home_player_2','home_player_3','home_player_4','home_player_5','home_player_6','home_player_7','home_player_8','home_player_9','home_player_10','home_player_11','away_player_1','away_player_2','away_player_2','away_player_3','away_player_4','away_player_5','away_player_6','away_player_7','away_player_8','away_player_9','away_player_10','away_player_11','B365H','B365D','B365A']].copy()
new_matches
# Out:
#       id     season  match_api_id  home_team_api_id  home_team_goal  \
# 0   4389  2015/2016       1987032              9825               0
# 1   4399  2015/2016       1988800              9825               2
# 2   4415  2015/2016       1988816             10003               0
# 3   4419  2015/2016       1988820              9825               1
# 4   4438  2015/2016       1988839              8659               2
# 5   4445  2015/2016       1988846              9850               1
# 6   4449  2015/2016       1988850              9825               3
# 7   4459  2015/2016       1988860             10252               0
# 8   4469  2015/2016       1988870              9825               2
# 9   4485  2015/2016       1988886              8466               4
# 10  4489  2015/2016       1988890              9825               2
# 11  4500  2015/2016       1987079              9826               1
# 12  4509  2015/2016       1988900              9825               1
# ...

# %%
pd.set_option('display.max_colwidth', None)

tables
# Out:
#     type               name           tbl_name  rootpage  \
# 0  table    sqlite_sequence    sqlite_sequence         4
# 1  table  Player_Attributes  Player_Attributes        11
# 2  table             Player             Player        14
# 3  table              Match              Match        18
# 4  table             League             League        24
# 5  table            Country            Country        26
# 6  table               Team               Team        29
# 7  table    Team_Attributes    Team_Attributes         2
#
# ...

# %%
#pd.set_option('display.max_colwidth', None)

player = pd.read_sql_query("SELECT * FROM 'Player_Attributes' Where date = \"2015-10-16 00:00:00\"", database)

# Descobrir chaves duplicadas (ta estatico, nao sei catar a linha)
ids = player["player_api_id"]
player[ids.isin(ids[ids.duplicated()])].sort_values("player_api_id")
player = player.drop(player.index[[1011]])

#Inner join pra pegar o overall dos jogadores
#inner_join_df= pd.merge(new_matches, player, on='player_api_id', how='inner')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12392/512265408.py in <module>
#       8 player = player.drop(player.index[[1011]])
#       9 #Inner join pra pegar o overall dos jogadores
# ---> 10 inner_join_df= pd.merge(new_matches, player, on='player_api_id', how='inner')
#
# c:\Users\sergi\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     109     validate: str | None = None,
#     110 ) -> DataFrame:
# --> 111     op = _MergeOperation(
#     112         left,
#     113         right,
#
# c:\Users\sergi\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
# ...
